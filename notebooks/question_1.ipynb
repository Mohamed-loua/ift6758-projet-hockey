# %% [markdown]
# # Sample code for Question 1
#
# This notebook shows how you can use the provided Python function to pull player stats from an online website.
# This function lives in a custom package that is provided to you in this repository.
# You are encouraged to leverage this package as a skeleton and add all of your reusable code, functions, etc. into relevant modules.
# This makes collaboration much easier as the package could be seen as a "single source of truth" to pull data, create visualizations, etc. rather than relying on a jumble of notebooks.
# You can still run into trouble if branches are not frequently merged as work progresses, so try to not let your branches diverge too much.

# %%
from src.StatsApiProxy import StatsApiProxy

data_proxy = StatsApiProxy()

# %% [markdown]
# If the above doesn't work for you, make sure you've installed the repo as specified in the readme file.
# Essentially you must make sure that your environment is setup (either through conda or virtualenv), and then install it using:
#
# ```bash
# pip install -e /path/to/repo
# ```
#
# The nice thing using this approach is if you have your environment activated, you can import modules from anywhere on your system!

# %%
df = data_proxy.get_player_stats(2016, 'goalies')
# Out:
# Retrieving data from 'https://www.hockey-reference.com/leagues/NHL_2016_goalies.html'...
# /Users/nicfillion/Public/IFT-6758-project/ift6758-projet-hockey/src/StatsApiProxy.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(players_multiple_teams, ignore_index=True)

# %% [markdown]
# If you're curious, this function uses the `pd.read_html()` method ([doc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_html.html)), which internally uses [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) to parse HTML data.

# %%
df.head()
# Out:
#   Rk             Player Age   Tm  GP  GS   W   L T/O   GA  ...   MIN  QS  \
# 0  1         Jake Allen  25  STL  47  44  26  15   3  101  ...  2583  26
# 1  2  Frederik Andersen  26  ANA  43  37  22   9   7   88  ...  2298  24
# 2  3     Craig Anderson  34  OTT  60  60  31  23   5  161  ...  3477  31
# 3  4    Richard Bachman  28  VAN   1   1   1   0   0    3  ...    60   0
# 4  5   Niklas Bäckström  37  CGY   4   3   2   2   0   13  ...   233   2
#
#     QS% RBS GA%-  GSAA  G  A PTS PIM
# 0  .591   6   94  6.28  0  0   0   0
# 1  .649   5   95  4.46  0  1   1   2
# 2  .517   8   99  2.05  0  2   2   0
# 3  .000   0  NaN   NaN  0  0   0   0
# 4  .667   1  NaN   NaN  0  0   0   0
#
# [5 rows x 26 columns]

# %%
data_proxy.fetch_live_data_for_years([2017, 2018, 2019, 2020, 2021], './hockey/test', False)
# Out:
# Starting process to dowload all data for season 2017-2018
# Path to directory is not valid, we will create a structure
# The directory was created
# Path to directory is not valid, we will create a structure
# The directory was created
# Regular season2017-2018 :
# --GAMEID 2017020001
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020001.json
# The request for game_id 2017020001 returned a 200
# --GAMEID 2017020002
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020002.json
# The request for game_id 2017020002 returned a 200
# --GAMEID 2017020003
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020003.json
# The request for game_id 2017020003 returned a 200
# --GAMEID 2017020004
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020004.json
# The request for game_id 2017020004 returned a 200
# --GAMEID 2017020005
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020005.json
# The request for game_id 2017020005 returned a 200
# --GAMEID 2017020006
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020006.json
# The request for game_id 2017020006 returned a 200
# --GAMEID 2017020007
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020007.json
# The request for game_id 2017020007 returned a 200
# --GAMEID 2017020008
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020008.json
# The request for game_id 2017020008 returned a 200
# --GAMEID 2017020009
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020009.json
# The request for game_id 2017020009 returned a 200
# --GAMEID 2017020010
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020010.json
# The request for game_id 2017020010 returned a 200
# --GAMEID 2017020011
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020011.json
# The request for game_id 2017020011 returned a 200
# --GAMEID 2017020012
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020012.json
# The request for game_id 2017020012 returned a 200
# --GAMEID 2017020013
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020013.json
# The request for game_id 2017020013 returned a 200
# --GAMEID 2017020014
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020014.json
# The request for game_id 2017020014 returned a 200
# --GAMEID 2017020015
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020015.json
# The request for game_id 2017020015 returned a 200
# --GAMEID 2017020016
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020016.json
# The request for game_id 2017020016 returned a 200
# --GAMEID 2017020017
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020017.json
# The request for game_id 2017020017 returned a 200
# --GAMEID 2017020018
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020018.json
# The request for game_id 2017020018 returned a 200
# --GAMEID 2017020019
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020019.json
# The request for game_id 2017020019 returned a 200
# --GAMEID 2017020020
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020020.json
# The request for game_id 2017020020 returned a 200
# --GAMEID 2017020021
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020021.json
# The request for game_id 2017020021 returned a 200
# --GAMEID 2017020022
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020022.json
# The request for game_id 2017020022 returned a 200
# --GAMEID 2017020023
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020023.json
# The request for game_id 2017020023 returned a 200
# --GAMEID 2017020024
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020024.json
# The request for game_id 2017020024 returned a 200
# --GAMEID 2017020025
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020025.json
# The request for game_id 2017020025 returned a 200
# --GAMEID 2017020026
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020026.json
# The request for game_id 2017020026 returned a 200
# --GAMEID 2017020027
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020027.json
# The request for game_id 2017020027 returned a 200
# --GAMEID 2017020028
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020028.json
# The request for game_id 2017020028 returned a 200
# --GAMEID 2017020029
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020029.json
# The request for game_id 2017020029 returned a 200
# --GAMEID 2017020030
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020030.json
# The request for game_id 2017020030 returned a 200
# --GAMEID 2017020031
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020031.json
# The request for game_id 2017020031 returned a 200
# --GAMEID 2017020032
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020032.json
# The request for game_id 2017020032 returned a 200
# --GAMEID 2017020033
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020033.json
# The request for game_id 2017020033 returned a 200
# --GAMEID 2017020034
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020034.json
# The request for game_id 2017020034 returned a 200
# --GAMEID 2017020035
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020035.json
# The request for game_id 2017020035 returned a 200
# --GAMEID 2017020036
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020036.json
# The request for game_id 2017020036 returned a 200
# --GAMEID 2017020037
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020037.json
# The request for game_id 2017020037 returned a 200
# --GAMEID 2017020038
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020038.json
# The request for game_id 2017020038 returned a 200
# --GAMEID 2017020039
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020039.json
# The request for game_id 2017020039 returned a 200
# --GAMEID 2017020040
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020040.json
# The request for game_id 2017020040 returned a 200
# --GAMEID 2017020041
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020041.json
# The request for game_id 2017020041 returned a 200
# --GAMEID 2017020042
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020042.json
# The request for game_id 2017020042 returned a 200
# --GAMEID 2017020043
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020043.json
# The request for game_id 2017020043 returned a 200
# --GAMEID 2017020044
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020044.json
# The request for game_id 2017020044 returned a 200
# --GAMEID 2017020045
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020045.json
# The request for game_id 2017020045 returned a 200
# --GAMEID 2017020046
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020046.json
# The request for game_id 2017020046 returned a 200
# --GAMEID 2017020047
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020047.json
# The request for game_id 2017020047 returned a 200
# --GAMEID 2017020048
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020048.json
# The request for game_id 2017020048 returned a 200
# --GAMEID 2017020049
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020049.json
# The request for game_id 2017020049 returned a 200
# --GAMEID 2017020050
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020050.json
# The request for game_id 2017020050 returned a 200
# --GAMEID 2017020051
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020051.json
# The request for game_id 2017020051 returned a 200
# --GAMEID 2017020052
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020052.json
# The request for game_id 2017020052 returned a 200
# --GAMEID 2017020053
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020053.json
# The request for game_id 2017020053 returned a 200
# --GAMEID 2017020054
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020054.json
# The request for game_id 2017020054 returned a 200
# --GAMEID 2017020055
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020055.json
# The request for game_id 2017020055 returned a 200
# --GAMEID 2017020056
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020056.json
# The request for game_id 2017020056 returned a 200
# --GAMEID 2017020057
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020057.json
# The request for game_id 2017020057 returned a 200
# --GAMEID 2017020058
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020058.json
# The request for game_id 2017020058 returned a 200
# --GAMEID 2017020059
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020059.json
# The request for game_id 2017020059 returned a 200
# --GAMEID 2017020060
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020060.json
# The request for game_id 2017020060 returned a 200
# --GAMEID 2017020061
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020061.json
# The request for game_id 2017020061 returned a 200
# --GAMEID 2017020062
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020062.json
# The request for game_id 2017020062 returned a 200
# --GAMEID 2017020063
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020063.json
# The request for game_id 2017020063 returned a 200
# --GAMEID 2017020064
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020064.json
# The request for game_id 2017020064 returned a 200
# --GAMEID 2017020065
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020065.json
# The request for game_id 2017020065 returned a 200
# --GAMEID 2017020066
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020066.json
# The request for game_id 2017020066 returned a 200
# --GAMEID 2017020067
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020067.json
# The request for game_id 2017020067 returned a 200
# --GAMEID 2017020068
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020068.json
# The request for game_id 2017020068 returned a 200
# --GAMEID 2017020069
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020069.json
# The request for game_id 2017020069 returned a 200
# --GAMEID 2017020070
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020070.json
# The request for game_id 2017020070 returned a 200
# --GAMEID 2017020071
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020071.json
# The request for game_id 2017020071 returned a 200
# --GAMEID 2017020072
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020072.json
# The request for game_id 2017020072 returned a 200
# --GAMEID 2017020073
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020073.json
# The request for game_id 2017020073 returned a 200
# --GAMEID 2017020074
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020074.json
# The request for game_id 2017020074 returned a 200
# --GAMEID 2017020075
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020075.json
# The request for game_id 2017020075 returned a 200
# --GAMEID 2017020076
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020076.json
# The request for game_id 2017020076 returned a 200
# --GAMEID 2017020077
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020077.json
# The request for game_id 2017020077 returned a 200
# --GAMEID 2017020078
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020078.json
# The request for game_id 2017020078 returned a 200
# --GAMEID 2017020079
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020079.json
# The request for game_id 2017020079 returned a 200
# --GAMEID 2017020080
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020080.json
# The request for game_id 2017020080 returned a 200
# --GAMEID 2017020081
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020081.json
# The request for game_id 2017020081 returned a 200
# --GAMEID 2017020082
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020082.json
# The request for game_id 2017020082 returned a 200
# --GAMEID 2017020083
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020083.json
# The request for game_id 2017020083 returned a 200
# --GAMEID 2017020084
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020084.json
# The request for game_id 2017020084 returned a 200
# --GAMEID 2017020085
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020085.json
# The request for game_id 2017020085 returned a 200
# --GAMEID 2017020086
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020086.json
# The request for game_id 2017020086 returned a 200
# --GAMEID 2017020087
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020087.json
# The request for game_id 2017020087 returned a 200
# --GAMEID 2017020088
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020088.json
# The request for game_id 2017020088 returned a 200
# --GAMEID 2017020089
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020089.json
# The request for game_id 2017020089 returned a 200
# --GAMEID 2017020090
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020090.json
# The request for game_id 2017020090 returned a 200
# --GAMEID 2017020091
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020091.json
# The request for game_id 2017020091 returned a 200
# --GAMEID 2017020092
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020092.json
# The request for game_id 2017020092 returned a 200
# --GAMEID 2017020093
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020093.json
# The request for game_id 2017020093 returned a 200
# --GAMEID 2017020094
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020094.json
# The request for game_id 2017020094 returned a 200
# --GAMEID 2017020095
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020095.json
# The request for game_id 2017020095 returned a 200
# --GAMEID 2017020096
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020096.json
# The request for game_id 2017020096 returned a 200
# --GAMEID 2017020097
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020097.json
# The request for game_id 2017020097 returned a 200
# --GAMEID 2017020098
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020098.json
# The request for game_id 2017020098 returned a 200
# --GAMEID 2017020099
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020099.json
# The request for game_id 2017020099 returned a 200
# --GAMEID 2017020100
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020100.json
# The request for game_id 2017020100 returned a 200
# --GAMEID 2017020101
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020101.json
# The request for game_id 2017020101 returned a 200
# --GAMEID 2017020102
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020102.json
# The request for game_id 2017020102 returned a 200
# --GAMEID 2017020103
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020103.json
# The request for game_id 2017020103 returned a 200
# --GAMEID 2017020104
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020104.json
# The request for game_id 2017020104 returned a 200
# --GAMEID 2017020105
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020105.json
# The request for game_id 2017020105 returned a 200
# --GAMEID 2017020106
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020106.json
# The request for game_id 2017020106 returned a 200
# --GAMEID 2017020107
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020107.json
# The request for game_id 2017020107 returned a 200
# --GAMEID 2017020108
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020108.json
# The request for game_id 2017020108 returned a 200
# --GAMEID 2017020109
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020109.json
# The request for game_id 2017020109 returned a 200
# --GAMEID 2017020110
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020110.json
# The request for game_id 2017020110 returned a 200
# --GAMEID 2017020111
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020111.json
# The request for game_id 2017020111 returned a 200
# --GAMEID 2017020112
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020112.json
# The request for game_id 2017020112 returned a 200
# --GAMEID 2017020113
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020113.json
# The request for game_id 2017020113 returned a 200
# --GAMEID 2017020114
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020114.json
# The request for game_id 2017020114 returned a 200
# --GAMEID 2017020115
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020115.json
# The request for game_id 2017020115 returned a 200
# --GAMEID 2017020116
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020116.json
# The request for game_id 2017020116 returned a 200
# --GAMEID 2017020117
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020117.json
# The request for game_id 2017020117 returned a 200
# --GAMEID 2017020118
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020118.json
# The request for game_id 2017020118 returned a 200
# --GAMEID 2017020119
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020119.json
# The request for game_id 2017020119 returned a 200
# --GAMEID 2017020120
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020120.json
# The request for game_id 2017020120 returned a 200
# --GAMEID 2017020121
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020121.json
# The request for game_id 2017020121 returned a 200
# --GAMEID 2017020122
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020122.json
# The request for game_id 2017020122 returned a 200
# --GAMEID 2017020123
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020123.json
# The request for game_id 2017020123 returned a 200
# --GAMEID 2017020124
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020124.json
# The request for game_id 2017020124 returned a 200
# --GAMEID 2017020125
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020125.json
# The request for game_id 2017020125 returned a 200
# --GAMEID 2017020126
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020126.json
# The request for game_id 2017020126 returned a 200
# --GAMEID 2017020127
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020127.json
# The request for game_id 2017020127 returned a 200
# --GAMEID 2017020128
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020128.json
# The request for game_id 2017020128 returned a 200
# --GAMEID 2017020129
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020129.json
# The request for game_id 2017020129 returned a 200
# --GAMEID 2017020130
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020130.json
# The request for game_id 2017020130 returned a 200
# --GAMEID 2017020131
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020131.json
# The request for game_id 2017020131 returned a 200
# --GAMEID 2017020132
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020132.json
# The request for game_id 2017020132 returned a 200
# --GAMEID 2017020133
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020133.json
# The request for game_id 2017020133 returned a 200
# --GAMEID 2017020134
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020134.json
# The request for game_id 2017020134 returned a 200
# --GAMEID 2017020135
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020135.json
# The request for game_id 2017020135 returned a 200
# --GAMEID 2017020136
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020136.json
# The request for game_id 2017020136 returned a 200
# --GAMEID 2017020137
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020137.json
# The request for game_id 2017020137 returned a 200
# --GAMEID 2017020138
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020138.json
# The request for game_id 2017020138 returned a 200
# --GAMEID 2017020139
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020139.json
# The request for game_id 2017020139 returned a 200
# --GAMEID 2017020140
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020140.json
# The request for game_id 2017020140 returned a 200
# --GAMEID 2017020141
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020141.json
# The request for game_id 2017020141 returned a 200
# --GAMEID 2017020142
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020142.json
# The request for game_id 2017020142 returned a 200
# --GAMEID 2017020143
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020143.json
# The request for game_id 2017020143 returned a 200
# --GAMEID 2017020144
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020144.json
# The request for game_id 2017020144 returned a 200
# --GAMEID 2017020145
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020145.json
# The request for game_id 2017020145 returned a 200
# --GAMEID 2017020146
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020146.json
# The request for game_id 2017020146 returned a 200
# --GAMEID 2017020147
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020147.json
# The request for game_id 2017020147 returned a 200
# --GAMEID 2017020148
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020148.json
# The request for game_id 2017020148 returned a 200
# --GAMEID 2017020149
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020149.json
# The request for game_id 2017020149 returned a 200
# --GAMEID 2017020150
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020150.json
# The request for game_id 2017020150 returned a 200
# --GAMEID 2017020151
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020151.json
# The request for game_id 2017020151 returned a 200
# --GAMEID 2017020152
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020152.json
# The request for game_id 2017020152 returned a 200
# --GAMEID 2017020153
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020153.json
# The request for game_id 2017020153 returned a 200
# --GAMEID 2017020154
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020154.json
# The request for game_id 2017020154 returned a 200
# --GAMEID 2017020155
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020155.json
# The request for game_id 2017020155 returned a 200
# --GAMEID 2017020156
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020156.json
# The request for game_id 2017020156 returned a 200
# --GAMEID 2017020157
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020157.json
# The request for game_id 2017020157 returned a 200
# --GAMEID 2017020158
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020158.json
# The request for game_id 2017020158 returned a 200
# --GAMEID 2017020159
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020159.json
# The request for game_id 2017020159 returned a 200
# --GAMEID 2017020160
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020160.json
# The request for game_id 2017020160 returned a 200
# --GAMEID 2017020161
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020161.json
# The request for game_id 2017020161 returned a 200
# --GAMEID 2017020162
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020162.json
# The request for game_id 2017020162 returned a 200
# --GAMEID 2017020163
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020163.json
# The request for game_id 2017020163 returned a 200
# --GAMEID 2017020164
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020164.json
# The request for game_id 2017020164 returned a 200
# --GAMEID 2017020165
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020165.json
# The request for game_id 2017020165 returned a 200
# --GAMEID 2017020166
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020166.json
# The request for game_id 2017020166 returned a 200
# --GAMEID 2017020167
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020167.json
# The request for game_id 2017020167 returned a 200
# --GAMEID 2017020168
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020168.json
# The request for game_id 2017020168 returned a 200
# --GAMEID 2017020169
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020169.json
# The request for game_id 2017020169 returned a 200
# --GAMEID 2017020170
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020170.json
# The request for game_id 2017020170 returned a 200
# --GAMEID 2017020171
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020171.json
# The request for game_id 2017020171 returned a 200
# --GAMEID 2017020172
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020172.json
# The request for game_id 2017020172 returned a 200
# --GAMEID 2017020173
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020173.json
# The request for game_id 2017020173 returned a 200
# --GAMEID 2017020174
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020174.json
# The request for game_id 2017020174 returned a 200
# --GAMEID 2017020175
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020175.json
# The request for game_id 2017020175 returned a 200
# --GAMEID 2017020176
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020176.json
# The request for game_id 2017020176 returned a 200
# --GAMEID 2017020177
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020177.json
# The request for game_id 2017020177 returned a 200
# --GAMEID 2017020178
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020178.json
# The request for game_id 2017020178 returned a 200
# --GAMEID 2017020179
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020179.json
# The request for game_id 2017020179 returned a 200
# --GAMEID 2017020180
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020180.json
# The request for game_id 2017020180 returned a 200
# --GAMEID 2017020181
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020181.json
# The request for game_id 2017020181 returned a 200
# --GAMEID 2017020182
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020182.json
# The request for game_id 2017020182 returned a 200
# --GAMEID 2017020183
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020183.json
# The request for game_id 2017020183 returned a 200
# --GAMEID 2017020184
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020184.json
# The request for game_id 2017020184 returned a 200
# --GAMEID 2017020185
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020185.json
# The request for game_id 2017020185 returned a 200
# --GAMEID 2017020186
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020186.json
# The request for game_id 2017020186 returned a 200
# --GAMEID 2017020187
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020187.json
# The request for game_id 2017020187 returned a 200
# --GAMEID 2017020188
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020188.json
# The request for game_id 2017020188 returned a 200
# --GAMEID 2017020189
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020189.json
# The request for game_id 2017020189 returned a 200
# --GAMEID 2017020190
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020190.json
# The request for game_id 2017020190 returned a 200
# --GAMEID 2017020191
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020191.json
# The request for game_id 2017020191 returned a 200
# --GAMEID 2017020192
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020192.json
# The request for game_id 2017020192 returned a 200
# --GAMEID 2017020193
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020193.json
# The request for game_id 2017020193 returned a 200
# --GAMEID 2017020194
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020194.json
# The request for game_id 2017020194 returned a 200
# --GAMEID 2017020195
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020195.json
# The request for game_id 2017020195 returned a 200
# --GAMEID 2017020196
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020196.json
# The request for game_id 2017020196 returned a 200
# --GAMEID 2017020197
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020197.json
# The request for game_id 2017020197 returned a 200
# --GAMEID 2017020198
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020198.json
# The request for game_id 2017020198 returned a 200
# --GAMEID 2017020199
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020199.json
# The request for game_id 2017020199 returned a 200
# --GAMEID 2017020200
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020200.json
# The request for game_id 2017020200 returned a 200
# --GAMEID 2017020201
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020201.json
# The request for game_id 2017020201 returned a 200
# --GAMEID 2017020202
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020202.json
# The request for game_id 2017020202 returned a 200
# --GAMEID 2017020203
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020203.json
# The request for game_id 2017020203 returned a 200
# --GAMEID 2017020204
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020204.json
# The request for game_id 2017020204 returned a 200
# --GAMEID 2017020205
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020205.json
# The request for game_id 2017020205 returned a 200
# --GAMEID 2017020206
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020206.json
# The request for game_id 2017020206 returned a 200
# --GAMEID 2017020207
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020207.json
# The request for game_id 2017020207 returned a 200
# --GAMEID 2017020208
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020208.json
# The request for game_id 2017020208 returned a 200
# --GAMEID 2017020209
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020209.json
# The request for game_id 2017020209 returned a 200
# --GAMEID 2017020210
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020210.json
# The request for game_id 2017020210 returned a 200
# --GAMEID 2017020211
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020211.json
# The request for game_id 2017020211 returned a 200
# --GAMEID 2017020212
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020212.json
# The request for game_id 2017020212 returned a 200
# --GAMEID 2017020213
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020213.json
# The request for game_id 2017020213 returned a 200
# --GAMEID 2017020214
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020214.json
# The request for game_id 2017020214 returned a 200
# --GAMEID 2017020215
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020215.json
# The request for game_id 2017020215 returned a 200
# --GAMEID 2017020216
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020216.json
# The request for game_id 2017020216 returned a 200
# --GAMEID 2017020217
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020217.json
# The request for game_id 2017020217 returned a 200
# --GAMEID 2017020218
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020218.json
# The request for game_id 2017020218 returned a 200
# --GAMEID 2017020219
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020219.json
# The request for game_id 2017020219 returned a 200
# --GAMEID 2017020220
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020220.json
# The request for game_id 2017020220 returned a 200
# --GAMEID 2017020221
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020221.json
# The request for game_id 2017020221 returned a 200
# --GAMEID 2017020222
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020222.json
# The request for game_id 2017020222 returned a 200
# --GAMEID 2017020223
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020223.json
# The request for game_id 2017020223 returned a 200
# --GAMEID 2017020224
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020224.json
# The request for game_id 2017020224 returned a 200
# --GAMEID 2017020225
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020225.json
# The request for game_id 2017020225 returned a 200
# --GAMEID 2017020226
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020226.json
# The request for game_id 2017020226 returned a 200
# --GAMEID 2017020227
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020227.json
# The request for game_id 2017020227 returned a 200
# --GAMEID 2017020228
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020228.json
# The request for game_id 2017020228 returned a 200
# --GAMEID 2017020229
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020229.json
# The request for game_id 2017020229 returned a 200
# --GAMEID 2017020230
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020230.json
# The request for game_id 2017020230 returned a 200
# --GAMEID 2017020231
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020231.json
# The request for game_id 2017020231 returned a 200
# --GAMEID 2017020232
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020232.json
# The request for game_id 2017020232 returned a 200
# --GAMEID 2017020233
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020233.json
# The request for game_id 2017020233 returned a 200
# --GAMEID 2017020234
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020234.json
# The request for game_id 2017020234 returned a 200
# --GAMEID 2017020235
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020235.json
# The request for game_id 2017020235 returned a 200
# --GAMEID 2017020236
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020236.json
# The request for game_id 2017020236 returned a 200
# --GAMEID 2017020237
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020237.json
# The request for game_id 2017020237 returned a 200
# --GAMEID 2017020238
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020238.json
# The request for game_id 2017020238 returned a 200
# --GAMEID 2017020239
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020239.json
# The request for game_id 2017020239 returned a 200
# --GAMEID 2017020240
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020240.json
# The request for game_id 2017020240 returned a 200
# --GAMEID 2017020241
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020241.json
# The request for game_id 2017020241 returned a 200
# --GAMEID 2017020242
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020242.json
# The request for game_id 2017020242 returned a 200
# --GAMEID 2017020243
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020243.json
# The request for game_id 2017020243 returned a 200
# --GAMEID 2017020244
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020244.json
# The request for game_id 2017020244 returned a 200
# --GAMEID 2017020245
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020245.json
# The request for game_id 2017020245 returned a 200
# --GAMEID 2017020246
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020246.json
# The request for game_id 2017020246 returned a 200
# --GAMEID 2017020247
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020247.json
# The request for game_id 2017020247 returned a 200
# --GAMEID 2017020248
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020248.json
# The request for game_id 2017020248 returned a 200
# --GAMEID 2017020249
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020249.json
# The request for game_id 2017020249 returned a 200
# --GAMEID 2017020250
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020250.json
# The request for game_id 2017020250 returned a 200
# --GAMEID 2017020251
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020251.json
# The request for game_id 2017020251 returned a 200
# --GAMEID 2017020252
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020252.json
# The request for game_id 2017020252 returned a 200
# --GAMEID 2017020253
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020253.json
# The request for game_id 2017020253 returned a 200
# --GAMEID 2017020254
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020254.json
# The request for game_id 2017020254 returned a 200
# --GAMEID 2017020255
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020255.json
# The request for game_id 2017020255 returned a 200
# --GAMEID 2017020256
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020256.json
# The request for game_id 2017020256 returned a 200
# --GAMEID 2017020257
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020257.json
# The request for game_id 2017020257 returned a 200
# --GAMEID 2017020258
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020258.json
# The request for game_id 2017020258 returned a 200
# --GAMEID 2017020259
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020259.json
# The request for game_id 2017020259 returned a 200
# --GAMEID 2017020260
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020260.json
# The request for game_id 2017020260 returned a 200
# --GAMEID 2017020261
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020261.json
# The request for game_id 2017020261 returned a 200
# --GAMEID 2017020262
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020262.json
# The request for game_id 2017020262 returned a 200
# --GAMEID 2017020263
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020263.json
# The request for game_id 2017020263 returned a 200
# --GAMEID 2017020264
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020264.json
# The request for game_id 2017020264 returned a 200
# --GAMEID 2017020265
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020265.json
# The request for game_id 2017020265 returned a 200
# --GAMEID 2017020266
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020266.json
# The request for game_id 2017020266 returned a 200
# --GAMEID 2017020267
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020267.json
# The request for game_id 2017020267 returned a 200
# --GAMEID 2017020268
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020268.json
# The request for game_id 2017020268 returned a 200
# --GAMEID 2017020269
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020269.json
# The request for game_id 2017020269 returned a 200
# --GAMEID 2017020270
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020270.json
# The request for game_id 2017020270 returned a 200
# --GAMEID 2017020271
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020271.json
# The request for game_id 2017020271 returned a 200
# --GAMEID 2017020272
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020272.json
# The request for game_id 2017020272 returned a 200
# --GAMEID 2017020273
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020273.json
# The request for game_id 2017020273 returned a 200
# --GAMEID 2017020274
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020274.json
# The request for game_id 2017020274 returned a 200
# --GAMEID 2017020275
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020275.json
# The request for game_id 2017020275 returned a 200
# --GAMEID 2017020276
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020276.json
# The request for game_id 2017020276 returned a 200
# --GAMEID 2017020277
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020277.json
# The request for game_id 2017020277 returned a 200
# --GAMEID 2017020278
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020278.json
# The request for game_id 2017020278 returned a 200
# --GAMEID 2017020279
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020279.json
# The request for game_id 2017020279 returned a 200
# --GAMEID 2017020280
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020280.json
# The request for game_id 2017020280 returned a 200
# --GAMEID 2017020281
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020281.json
# The request for game_id 2017020281 returned a 200
# --GAMEID 2017020282
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020282.json
# The request for game_id 2017020282 returned a 200
# --GAMEID 2017020283
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020283.json
# The request for game_id 2017020283 returned a 200
# --GAMEID 2017020284
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020284.json
# The request for game_id 2017020284 returned a 200
# --GAMEID 2017020285
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020285.json
# The request for game_id 2017020285 returned a 200
# --GAMEID 2017020286
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020286.json
# The request for game_id 2017020286 returned a 200
# --GAMEID 2017020287
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020287.json
# The request for game_id 2017020287 returned a 200
# --GAMEID 2017020288
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020288.json
# The request for game_id 2017020288 returned a 200
# --GAMEID 2017020289
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020289.json
# The request for game_id 2017020289 returned a 200
# --GAMEID 2017020290
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020290.json
# The request for game_id 2017020290 returned a 200
# --GAMEID 2017020291
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020291.json
# The request for game_id 2017020291 returned a 200
# --GAMEID 2017020292
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020292.json
# The request for game_id 2017020292 returned a 200
# --GAMEID 2017020293
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020293.json
# The request for game_id 2017020293 returned a 200
# --GAMEID 2017020294
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020294.json
# The request for game_id 2017020294 returned a 200
# --GAMEID 2017020295
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020295.json
# The request for game_id 2017020295 returned a 200
# --GAMEID 2017020296
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020296.json
# The request for game_id 2017020296 returned a 200
# --GAMEID 2017020297
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020297.json
# The request for game_id 2017020297 returned a 200
# --GAMEID 2017020298
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020298.json
# The request for game_id 2017020298 returned a 200
# --GAMEID 2017020299
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020299.json
# The request for game_id 2017020299 returned a 200
# --GAMEID 2017020300
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020300.json
# The request for game_id 2017020300 returned a 200
# --GAMEID 2017020301
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020301.json
# The request for game_id 2017020301 returned a 200
# --GAMEID 2017020302
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020302.json
# The request for game_id 2017020302 returned a 200
# --GAMEID 2017020303
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020303.json
# The request for game_id 2017020303 returned a 200
# --GAMEID 2017020304
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020304.json
# The request for game_id 2017020304 returned a 200
# --GAMEID 2017020305
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020305.json
# The request for game_id 2017020305 returned a 200
# --GAMEID 2017020306
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020306.json
# The request for game_id 2017020306 returned a 200
# --GAMEID 2017020307
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020307.json
# The request for game_id 2017020307 returned a 200
# --GAMEID 2017020308
# --Data will be saved at ./hockey/test/Season20172018/Regular20172018/2017020308.json
# The request for game_id 2017020308 returned a 200
# ...
# The request for game_id 2021030182 returned a 200
# --GAMEID 2021030183
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030183.json
# The request for game_id 2021030183 returned a 200
# --GAMEID 2021030184
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030184.json
# The request for game_id 2021030184 returned a 200
# --GAMEID 2021030185
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030185.json
# The request for game_id 2021030185 returned a 200
# --GAMEID 2021030186
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030186.json
# The request for game_id 2021030186 returned a 200
# --GAMEID 2021030187
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030187.json
# The request for game_id 2021030187 returned a 200
# --GAMEID 2021030191
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030191.json
# The request for game_id 2021030191 returned a 404
# dowload for game_id : 2021030191 failed, return code was 404
# --GAMEID 2021030192
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030192.json
# The request for game_id 2021030192 returned a 404
# dowload for game_id : 2021030192 failed, return code was 404
# --GAMEID 2021030193
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030193.json
# The request for game_id 2021030193 returned a 404
# dowload for game_id : 2021030193 failed, return code was 404
# --GAMEID 2021030194
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030194.json
# The request for game_id 2021030194 returned a 404
# dowload for game_id : 2021030194 failed, return code was 404
# --GAMEID 2021030195
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030195.json
# The request for game_id 2021030195 returned a 404
# dowload for game_id : 2021030195 failed, return code was 404
# --GAMEID 2021030196
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030196.json
# The request for game_id 2021030196 returned a 404
# dowload for game_id : 2021030196 failed, return code was 404
# --GAMEID 2021030197
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030197.json
# The request for game_id 2021030197 returned a 404
# dowload for game_id : 2021030197 failed, return code was 404
# --GAMEID 2021030211
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030211.json
# The request for game_id 2021030211 returned a 200
# --GAMEID 2021030212
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030212.json
# The request for game_id 2021030212 returned a 200
# --GAMEID 2021030213
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030213.json
# The request for game_id 2021030213 returned a 200
# --GAMEID 2021030214
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030214.json
# The request for game_id 2021030214 returned a 200
# --GAMEID 2021030215
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030215.json
# The request for game_id 2021030215 returned a 200
# --GAMEID 2021030216
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030216.json
# The request for game_id 2021030216 returned a 200
# --GAMEID 2021030217
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030217.json
# The request for game_id 2021030217 returned a 200
# --GAMEID 2021030221
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030221.json
# The request for game_id 2021030221 returned a 200
# --GAMEID 2021030222
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030222.json
# The request for game_id 2021030222 returned a 200
# --GAMEID 2021030223
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030223.json
# The request for game_id 2021030223 returned a 200
# --GAMEID 2021030224
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030224.json
# The request for game_id 2021030224 returned a 200
# --GAMEID 2021030225
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030225.json
# The request for game_id 2021030225 returned a 200
# --GAMEID 2021030226
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030226.json
# The request for game_id 2021030226 returned a 200
# --GAMEID 2021030227
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030227.json
# The request for game_id 2021030227 returned a 200
# --GAMEID 2021030231
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030231.json
# The request for game_id 2021030231 returned a 200
# --GAMEID 2021030232
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030232.json
# The request for game_id 2021030232 returned a 200
# --GAMEID 2021030233
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030233.json
# The request for game_id 2021030233 returned a 200
# --GAMEID 2021030234
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030234.json
# The request for game_id 2021030234 returned a 200
# --GAMEID 2021030235
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030235.json
# The request for game_id 2021030235 returned a 200
# --GAMEID 2021030236
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030236.json
# The request for game_id 2021030236 returned a 200
# --GAMEID 2021030237
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030237.json
# The request for game_id 2021030237 returned a 200
# --GAMEID 2021030241
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030241.json
# The request for game_id 2021030241 returned a 200
# --GAMEID 2021030242
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030242.json
# The request for game_id 2021030242 returned a 200
# --GAMEID 2021030243
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030243.json
# The request for game_id 2021030243 returned a 200
# --GAMEID 2021030244
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030244.json
# The request for game_id 2021030244 returned a 200
# --GAMEID 2021030245
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030245.json
# The request for game_id 2021030245 returned a 200
# --GAMEID 2021030246
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030246.json
# The request for game_id 2021030246 returned a 200
# --GAMEID 2021030247
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030247.json
# The request for game_id 2021030247 returned a 200
# --GAMEID 2021030251
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030251.json
# The request for game_id 2021030251 returned a 404
# dowload for game_id : 2021030251 failed, return code was 404
# --GAMEID 2021030252
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030252.json
# The request for game_id 2021030252 returned a 404
# dowload for game_id : 2021030252 failed, return code was 404
# --GAMEID 2021030253
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030253.json
# The request for game_id 2021030253 returned a 404
# dowload for game_id : 2021030253 failed, return code was 404
# --GAMEID 2021030254
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030254.json
# The request for game_id 2021030254 returned a 404
# dowload for game_id : 2021030254 failed, return code was 404
# --GAMEID 2021030255
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030255.json
# The request for game_id 2021030255 returned a 404
# dowload for game_id : 2021030255 failed, return code was 404
# --GAMEID 2021030256
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030256.json
# The request for game_id 2021030256 returned a 404
# dowload for game_id : 2021030256 failed, return code was 404
# --GAMEID 2021030257
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030257.json
# The request for game_id 2021030257 returned a 404
# dowload for game_id : 2021030257 failed, return code was 404
# --GAMEID 2021030311
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030311.json
# The request for game_id 2021030311 returned a 200
# --GAMEID 2021030312
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030312.json
# The request for game_id 2021030312 returned a 200
# --GAMEID 2021030313
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030313.json
# The request for game_id 2021030313 returned a 200
# --GAMEID 2021030314
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030314.json
# The request for game_id 2021030314 returned a 200
# --GAMEID 2021030315
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030315.json
# The request for game_id 2021030315 returned a 200
# --GAMEID 2021030316
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030316.json
# The request for game_id 2021030316 returned a 200
# --GAMEID 2021030317
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030317.json
# The request for game_id 2021030317 returned a 200
# --GAMEID 2021030321
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030321.json
# The request for game_id 2021030321 returned a 200
# --GAMEID 2021030322
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030322.json
# The request for game_id 2021030322 returned a 200
# --GAMEID 2021030323
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030323.json
# The request for game_id 2021030323 returned a 200
# --GAMEID 2021030324
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030324.json
# The request for game_id 2021030324 returned a 200
# --GAMEID 2021030325
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030325.json
# The request for game_id 2021030325 returned a 200
# --GAMEID 2021030326
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030326.json
# The request for game_id 2021030326 returned a 200
# --GAMEID 2021030327
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030327.json
# The request for game_id 2021030327 returned a 200
# --GAMEID 2021030331
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030331.json
# The request for game_id 2021030331 returned a 404
# dowload for game_id : 2021030331 failed, return code was 404
# --GAMEID 2021030332
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030332.json
# The request for game_id 2021030332 returned a 404
# dowload for game_id : 2021030332 failed, return code was 404
# --GAMEID 2021030333
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030333.json
# The request for game_id 2021030333 returned a 404
# dowload for game_id : 2021030333 failed, return code was 404
# --GAMEID 2021030334
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030334.json
# The request for game_id 2021030334 returned a 404
# dowload for game_id : 2021030334 failed, return code was 404
# --GAMEID 2021030335
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030335.json
# The request for game_id 2021030335 returned a 404
# dowload for game_id : 2021030335 failed, return code was 404
# --GAMEID 2021030336
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030336.json
# The request for game_id 2021030336 returned a 404
# dowload for game_id : 2021030336 failed, return code was 404
# --GAMEID 2021030337
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030337.json
# The request for game_id 2021030337 returned a 404
# dowload for game_id : 2021030337 failed, return code was 404
# --GAMEID 2021030411
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030411.json
# The request for game_id 2021030411 returned a 200
# --GAMEID 2021030412
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030412.json
# The request for game_id 2021030412 returned a 200
# --GAMEID 2021030413
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030413.json
# The request for game_id 2021030413 returned a 200
# --GAMEID 2021030414
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030414.json
# The request for game_id 2021030414 returned a 200
# --GAMEID 2021030415
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030415.json
# The request for game_id 2021030415 returned a 200
# --GAMEID 2021030416
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030416.json
# The request for game_id 2021030416 returned a 200
# --GAMEID 2021030417
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030417.json
# The request for game_id 2021030417 returned a 200
# --GAMEID 2021030421
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030421.json
# The request for game_id 2021030421 returned a 404
# dowload for game_id : 2021030421 failed, return code was 404
# --GAMEID 2021030422
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030422.json
# The request for game_id 2021030422 returned a 404
# dowload for game_id : 2021030422 failed, return code was 404
# --GAMEID 2021030423
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030423.json
# The request for game_id 2021030423 returned a 404
# dowload for game_id : 2021030423 failed, return code was 404
# --GAMEID 2021030424
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030424.json
# The request for game_id 2021030424 returned a 404
# dowload for game_id : 2021030424 failed, return code was 404
# --GAMEID 2021030425
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030425.json
# The request for game_id 2021030425 returned a 404
# dowload for game_id : 2021030425 failed, return code was 404
# --GAMEID 2021030426
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030426.json
# The request for game_id 2021030426 returned a 404
# dowload for game_id : 2021030426 failed, return code was 404
# --GAMEID 2021030427
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030427.json
# The request for game_id 2021030427 returned a 404
# dowload for game_id : 2021030427 failed, return code was 404
# --GAMEID 2021030511
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030511.json
# The request for game_id 2021030511 returned a 404
# dowload for game_id : 2021030511 failed, return code was 404
# --GAMEID 2021030512
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030512.json
# The request for game_id 2021030512 returned a 404
# dowload for game_id : 2021030512 failed, return code was 404
# --GAMEID 2021030513
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030513.json
# The request for game_id 2021030513 returned a 404
# dowload for game_id : 2021030513 failed, return code was 404
# --GAMEID 2021030514
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030514.json
# The request for game_id 2021030514 returned a 404
# dowload for game_id : 2021030514 failed, return code was 404
# --GAMEID 2021030515
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030515.json
# The request for game_id 2021030515 returned a 404
# dowload for game_id : 2021030515 failed, return code was 404
# --GAMEID 2021030516
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030516.json
# The request for game_id 2021030516 returned a 404
# dowload for game_id : 2021030516 failed, return code was 404
# --GAMEID 2021030517
# --Data will be saved at ./hockey/test/Season20212022/Playoff20212022/2021030517.json
# The request for game_id 2021030517 returned a 404
# dowload for game_id : 2021030517 failed, return code was 404
