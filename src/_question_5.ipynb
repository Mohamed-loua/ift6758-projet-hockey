# %%
import pandas as pd
import numpy as np
import os
import os as path
import json
import requests
import seaborn as sns
import matplotlib.pyplot as plt
from DataExtractor import DataExtractor
sns.set()

# %%
path = os.getcwd()
path
# Out:
# 'C:\\Users\\jonathan\\Documents\\university\\python-homework\\ift6758-projet-hockey\\src'

# %%
# !pip install -e C:\Users\jonathan\Documents\university\python-homework\ift6758-projet-hockey
# Out:
# Obtaining file:///C:/Users/jonathan/Documents/university/python-homework/ift6758-projet-hockey
# Installing collected packages: ift6758
#   Running setup.py develop for ift6758
# Successfully installed ift6758-0.1.0

# %%
data_extractor = DataExtractor()
df_season_2017 = data_extractor.get_season_into_dataframe('./../ift6758/data/hockey/test/Season20172018/season20172018.json')
df_season_2018 = data_extractor.get_season_into_dataframe('./../ift6758/data/hockey/test/Season20182019/season20182019.json')
df_season_2019 = data_extractor.get_season_into_dataframe('./../ift6758/data/hockey/test/Season20192020/season20192020.json')
df_season_2020 = data_extractor.get_season_into_dataframe('./../ift6758/data/hockey/test/Season20202021/season20202021.json')
df_season_2021 = data_extractor.get_season_into_dataframe('./../ift6758/data/hockey/test/Season20212022/season20212022.json')
# Out:
# Get all games from a single season
# Working on game 2017020001
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020002
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020003
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020004
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020005
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020006
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020007
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020008
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020009
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020010
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020011
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020012
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020013
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020014
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020015
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020016
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020017
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020018
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020019
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020020
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020021
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020022
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020023
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020024
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020025
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020026
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020027
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020028
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020029
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020030
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020031
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020032
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020033
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020034
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020035
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020036
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020037
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020038
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020039
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020040
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020041
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020042
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020043
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020044
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020045
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020046
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020047
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020048
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020049
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020050
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020051
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020052
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020053
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020054
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020055
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020056
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020057
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020058
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020059
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020060
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020061
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020062
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020063
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020064
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020065
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020066
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020067
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020068
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020069
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020070
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020071
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020072
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020073
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020074
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020075
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020076
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020077
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020078
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020079
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020080
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020081
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020082
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020083
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020084
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020085
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020086
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020087
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020088
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020089
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020090
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020091
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020092
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020093
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020094
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020095
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020096
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020097
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020098
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020099
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020100
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020101
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020102
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020103
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020104
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020105
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020106
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020107
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020108
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020109
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020110
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020111
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020112
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020113
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020114
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020115
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020116
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020117
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020118
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020119
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020120
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020121
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020122
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020123
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020124
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020125
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020126
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020127
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020128
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020129
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020130
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020131
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020132
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020133
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020134
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020135
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020136
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020137
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020138
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020139
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020140
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020141
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020142
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020143
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020144
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020145
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020146
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020147
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020148
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020149
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020150
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020151
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020152
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020153
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020154
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020155
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020156
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020157
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020158
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020159
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020160
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020161
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020162
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020163
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020164
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020165
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020166
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020167
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020168
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020169
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020170
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020171
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020172
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020173
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020174
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020175
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020176
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020177
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020178
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020179
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020180
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020181
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020182
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020183
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020184
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020185
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020186
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020187
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020188
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020189
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020190
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020191
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020192
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020193
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020194
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020195
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020196
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020197
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020198
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020199
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020200
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020201
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020202
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020203
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020204
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020205
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020206
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020207
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020208
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020209
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020210
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020211
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020212
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020213
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020214
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020215
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020216
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020217
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020218
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020219
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020220
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020221
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020222
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020223
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020224
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020225
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020226
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020227
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020228
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020229
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020230
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020231
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020232
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020233
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020234
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020235
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020236
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020237
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020238
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020239
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020240
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020241
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020242
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020243
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020244
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020245
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020246
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020247
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020248
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020249
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020250
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020251
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020252
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020253
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020254
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020255
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020256
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020257
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020258
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020259
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020260
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020261
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020262
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020263
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020264
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020265
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020266
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020267
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020268
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020269
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020270
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020271
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020272
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020273
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020274
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020275
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020276
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020277
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020278
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020279
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020280
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020281
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020282
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020283
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020284
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020285
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020286
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020287
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020288
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020289
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020290
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020291
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020292
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020293
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020294
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020295
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020296
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020297
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020298
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020299
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020300
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020301
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020302
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020303
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020304
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020305
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020306
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020307
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020308
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020309
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020310
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020311
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020312
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020313
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020314
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020315
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020316
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020317
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020318
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020319
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020320
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020321
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020322
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020323
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020324
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020325
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020326
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020327
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020328
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020329
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020330
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020331
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020332
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020333
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020334
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020335
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020336
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020337
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020338
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020339
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020340
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020341
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020342
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020343
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020344
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020345
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020346
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020347
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020348
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020349
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020350
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020351
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020352
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020353
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020354
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020355
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020356
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020357
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020358
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020359
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020360
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020361
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020362
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020363
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020364
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020365
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020366
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020367
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020368
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020369
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020370
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020371
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020372
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020373
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020374
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020375
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020376
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020377
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020378
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020379
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020380
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020381
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020382
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020383
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020384
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020385
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020386
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020387
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020388
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020389
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020390
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020391
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020392
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020393
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020394
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020395
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020396
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020397
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020398
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020399
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020400
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020401
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020402
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020403
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020404
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020405
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020406
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020407
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020408
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020409
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020410
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020411
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020412
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020413
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020414
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020415
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020416
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020417
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020418
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020419
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020420
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020421
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020422
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020423
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020424
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2017020425
# Game was cleaned
# ...
# Game was added to main DataFrame
# Working on game 2021021277
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021278
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021279
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021280
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021281
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021282
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021283
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021284
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021285
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021286
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021287
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021288
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021289
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021290
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021291
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021292
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021293
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021294
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021295
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021296
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021297
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021298
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021299
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021300
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021301
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021302
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021303
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021304
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021305
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021306
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021307
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021308
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021309
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021310
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021311
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021021312
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030111
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030112
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030113
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030114
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030115
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030116
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030117
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030121
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030122
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030123
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030124
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030125
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030126
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030127
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030131
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030132
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030133
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030134
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030135
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030136
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030137
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030141
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030142
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030143
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030144
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030145
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030146
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030147
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030151
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030152
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030153
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030154
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030155
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030156
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030157
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030161
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030162
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030163
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030164
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030165
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030166
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030167
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030171
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030172
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030173
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030174
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030175
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030176
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030177
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030181
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030182
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030183
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030184
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030185
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030186
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030187
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030211
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030212
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030213
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030214
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030215
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030216
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030217
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030221
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030222
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030223
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030224
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030225
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030226
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030227
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030231
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030232
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030233
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030234
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030235
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030236
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030237
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030241
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030242
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030243
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030244
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030245
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030246
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030247
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030311
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030312
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030313
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030314
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030315
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030316
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030317
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030321
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030322
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030323
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030324
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030325
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030326
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030327
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030411
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030412
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030413
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030414
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030415
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030416
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame
# Working on game 2021030417
# Game was cleaned
# Game was transformed into DataFrame
# Game was added to main DataFrame

# %%
df_season_2017.head()
# Out:
#   about.periodTime about.eventId            team.name result.eventTypeId  \
# 0            00:38            54        Winnipeg Jets               SHOT
# 1            00:49            55        Winnipeg Jets               SHOT
# 2            01:03            58        Winnipeg Jets               SHOT
# 3            01:46            62  Toronto Maple Leafs               SHOT
# 4            03:42            68        Winnipeg Jets               SHOT
#
#   coordinates.x coordinates.y players.0.player.fullName  \
# 0         -36.0         -28.0            Josh Morrissey
# 1         -75.0           1.0            Shawn Matthias
# 2         -73.0          10.0              Bryan Little
# 3          80.0          -3.0                 Eric Fehr
# 4         -44.0         -21.0              Patrik Laine
#
#   players.1.player.fullName result.secondaryType result.strength.code  \
# 0         Frederik Andersen           Wrist Shot                 None
# 1         Frederik Andersen           Wrist Shot                 None
# 2         Frederik Andersen             Backhand                 None
# 3               Steve Mason           Wrist Shot                 None
# 4         Frederik Andersen            Snap Shot                 None
#
#   result.emptyNet
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
df_season_2018.head()
# Out:
#   about.periodTime about.eventId            team.name result.eventTypeId  \
# 0            00:29            10   Montréal Canadiens               SHOT
# 1            00:49            11  Toronto Maple Leafs               SHOT
# 2            01:00            12   Montréal Canadiens               SHOT
# 3            03:54            18   Montréal Canadiens               SHOT
# 4            04:06            20   Montréal Canadiens               SHOT
#
#   coordinates.x coordinates.y players.0.player.fullName  \
# 0          78.0         -19.0          Artturi Lehkonen
# 1         -37.0         -10.0             Morgan Rielly
# 2          47.0         -23.0         Brendan Gallagher
# 3          53.0          14.0         Brendan Gallagher
# 4          77.0          -2.0               Mike Reilly
#
#   players.1.player.fullName result.secondaryType result.strength.code  \
# 0         Frederik Andersen             Backhand                 None
# 1               Carey Price            Snap Shot                 None
# 2         Frederik Andersen           Wrist Shot                 None
# 3         Frederik Andersen            Snap Shot                 None
# 4         Frederik Andersen            Snap Shot                 None
#
#   result.emptyNet
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
df_season_2019.head()
# Out:
#   about.periodTime about.eventId            team.name result.eventTypeId  \
# 0            00:25            10      Ottawa Senators               GOAL
# 1            01:31            15  Toronto Maple Leafs               SHOT
# 2            03:23            20      Ottawa Senators               SHOT
# 3            03:56            21  Toronto Maple Leafs               SHOT
# 4            04:47            24  Toronto Maple Leafs               SHOT
#
#   coordinates.x coordinates.y players.0.player.fullName  \
# 0          85.0          -1.0             Brady Tkachuk
# 1         -32.0          -2.0             Morgan Rielly
# 2          63.0          -6.0              Dylan DeMelo
# 3         -59.0         -20.0             Morgan Rielly
# 4         -42.0         -29.0              Tyson Barrie
#
#   players.1.player.fullName result.secondaryType result.strength.code  \
# 0         Frederik Andersen               Tip-In                 EVEN
# 1            Craig Anderson            Snap Shot                 None
# 2         Frederik Andersen            Snap Shot                 None
# 3            Craig Anderson           Wrist Shot                 None
# 4            Craig Anderson            Slap Shot                 None
#
#   result.emptyNet
# 0           False
# 1            None
# 2            None
# 3            None
# 4            None

# %%
df_season_2020.head()
# Out:
#   about.periodTime about.eventId            team.name result.eventTypeId  \
# 0            00:16            53  Philadelphia Flyers               SHOT
# 1            00:34             9  Pittsburgh Penguins               SHOT
# 2            01:05            55  Philadelphia Flyers               SHOT
# 3            02:51            62  Pittsburgh Penguins               SHOT
# 4            03:44            65  Philadelphia Flyers               SHOT
#
#    coordinates.x  coordinates.y players.0.player.fullName  \
# 0          -74.0           29.0            Travis Konecny
# 1           49.0          -25.0            Evan Rodrigues
# 2          -52.0          -31.0              Joel Farabee
# 3           43.0           39.0            Evan Rodrigues
# 4          -53.0            8.0             Claude Giroux
#
#   players.1.player.fullName result.secondaryType result.strength.code  \
# 0             Tristan Jarry           Wrist Shot                 None
# 1               Carter Hart           Wrist Shot                 None
# 2             Tristan Jarry             Backhand                 None
# 3               Carter Hart            Snap Shot                 None
# 4             Tristan Jarry            Slap Shot                 None
#
#   result.emptyNet
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
df_season_2021.head()
# Out:
#   about.periodTime about.eventId            team.name result.eventTypeId  \
# 0            01:03            54  Tampa Bay Lightning               SHOT
# 1            01:44            57  Pittsburgh Penguins               SHOT
# 2            02:01            58  Tampa Bay Lightning               SHOT
# 3            02:47            60  Pittsburgh Penguins               SHOT
# 4            03:07            62  Tampa Bay Lightning               SHOT
#
#    coordinates.x  coordinates.y players.0.player.fullName  \
# 0           61.0          -32.0            Steven Stamkos
# 1          -65.0           19.0              Brock McGinn
# 2           -8.0          -27.0                 Jan Rutta
# 3          -60.0           -4.0             Danton Heinen
# 4           63.0            4.0              Ondrej Palat
#
#   players.1.player.fullName result.secondaryType result.strength.code  \
# 0             Tristan Jarry           Wrist Shot                 None
# 1        Andrei Vasilevskiy           Wrist Shot                 None
# 2             Tristan Jarry           Wrist Shot                 None
# 3        Andrei Vasilevskiy           Wrist Shot                 None
# 4             Tristan Jarry           Wrist Shot                 None
#
#   result.emptyNet
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
season_2017_df = df_season_2017.copy()
season_2018_df = df_season_2018.copy()
season_2019_df = df_season_2019.copy()
season_2020_df = df_season_2020.copy()
season_2021_df = df_season_2021.copy()

season_2017_df.drop(['about.periodTime','about.eventId','team.name','coordinates.y','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
season_2018_df.drop(['about.periodTime','about.eventId','team.name','coordinates.y','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
season_2019_df.drop(['about.periodTime','about.eventId','team.name','coordinates.y','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
season_2020_df.drop(['about.periodTime','about.eventId','team.name','coordinates.y','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
season_2021_df.drop(['about.periodTime','about.eventId','team.name','coordinates.y','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)

# %%
season_2017_df.rename(columns={'result.secondaryType':'type_of_shot', 'result.eventTypeId':'type_of_shot_id', 'coordinates.x':'count'}, inplace=True)
season_2017_df_shot_type = season_2017_df.groupby(['type_of_shot', 'type_of_shot_id'])['count'].count().reset_index()

season_2018_df.rename(columns={'result.secondaryType':'type_of_shot', 'result.eventTypeId':'type_of_shot_id', 'coordinates.x':'count'}, inplace=True)
season_2018_df_shot_type = season_2018_df.groupby(['type_of_shot', 'type_of_shot_id'])['count'].count().reset_index()

season_2019_df.rename(columns={'result.secondaryType':'type_of_shot', 'result.eventTypeId':'type_of_shot_id', 'coordinates.x':'count'}, inplace=True)
season_2019_df_shot_type = season_2019_df.groupby(['type_of_shot', 'type_of_shot_id'])['count'].count().reset_index()

season_2020_df.rename(columns={'result.secondaryType':'type_of_shot', 'result.eventTypeId':'type_of_shot_id', 'coordinates.x':'count'}, inplace=True)
season_2020_df_shot_type = season_2020_df.groupby(['type_of_shot', 'type_of_shot_id'])['count'].count().reset_index()

season_2021_df.rename(columns={'result.secondaryType':'type_of_shot', 'result.eventTypeId':'type_of_shot_id', 'coordinates.x':'count'}, inplace=True)
season_2021_df_shot_type = season_2021_df.groupby(['type_of_shot', 'type_of_shot_id'])['count'].count().reset_index()

# %%
season_2017_df_shots = season_2017_df_shot_type.groupby('type_of_shot').sum().reset_index()
season_2017_df_goals = season_2017_df_shot_type.query('type_of_shot_id == "GOAL"').reset_index(drop=True)

season_2018_df_shots = season_2018_df_shot_type.groupby('type_of_shot').sum().reset_index()
season_2018_df_goals = season_2018_df_shot_type.query('type_of_shot_id == "GOAL"').reset_index(drop=True)

season_2019_df_shots = season_2019_df_shot_type.groupby('type_of_shot').sum().reset_index()
season_2019_df_goals = season_2019_df_shot_type.query('type_of_shot_id == "GOAL"').reset_index(drop=True)

season_2020_df_shots = season_2020_df_shot_type.groupby('type_of_shot').sum().reset_index()
season_2020_df_goals = season_2020_df_shot_type.query('type_of_shot_id == "GOAL"').reset_index(drop=True)

season_2021_df_shots = season_2021_df_shot_type.groupby('type_of_shot').sum().reset_index()
season_2021_df_goals = season_2021_df_shot_type.query('type_of_shot_id == "GOAL"').reset_index(drop=True)

# %%
season_2017_df_shots
# Out:
#   type_of_shot  count
# 0     Backhand   7077
# 1    Deflected   1450
# 2    Slap Shot  14279
# 3    Snap Shot  12465
# 4       Tip-In   4449
# 5  Wrap-around    893
# 6   Wrist Shot  46513

# %%
season_2017_df_goals
# Out:
#   type_of_shot type_of_shot_id  count
# 0     Backhand            GOAL    808
# 1    Deflected            GOAL    262
# 2    Slap Shot            GOAL    889
# 3    Snap Shot            GOAL   1168
# 4       Tip-In            GOAL    760
# 5  Wrap-around            GOAL     60
# 6   Wrist Shot            GOAL   4235

# %%
plt.bar(season_2017_df_shots['type_of_shot'], season_2017_df_shots['count'], label="tire au but", color='b')
plt.bar(season_2017_df_goals['type_of_shot'], season_2017_df_goals['count'], label="but", color='g')
plt.plot()

plt.xlabel("type de tir au but")
plt.ylabel("nombre de tirs")
plt.title("Le nombre de tirs au but contre le nombre de but selon chaque type de tirs pour la saison 2017")
plt.legend()
plt.show()

# %%
plt.bar(season_2018_df_shots['type_of_shot'], season_2018_df_shots['count'], label="tire au but", color='b')
plt.bar(season_2018_df_goals['type_of_shot'], season_2018_df_goals['count'], label="but", color='g')
plt.plot()

plt.xlabel("type de tir au but")
plt.ylabel("nombre de tirs")
plt.title("Le nombre de tirs au but contre le nombre de but selon chaque type de tirs pour la saison 2018")
plt.legend()
plt.show()

# %%
plt.bar(season_2019_df_shots['type_of_shot'], season_2019_df_shots['count'], label="tire au but", color='b')
plt.bar(season_2019_df_goals['type_of_shot'], season_2019_df_goals['count'], label="but", color='g')
plt.plot()

plt.xlabel("type de tir au but")
plt.ylabel("nombre de tirs")
plt.title("Le nombre de tirs au but contre le nombre de but selon chaque type de tirs pour la saison 2019")
plt.legend()
plt.show()

# %%
plt.bar(season_2020_df_shots['type_of_shot'], season_2020_df_shots['count'], label="tire au but", color='b')
plt.bar(season_2020_df_goals['type_of_shot'], season_2020_df_goals['count'], label="but", color='g')
plt.plot()

plt.xlabel("type de tir au but")
plt.ylabel("nombre de tirs")
plt.title("Le nombre de tirs au but contre le nombre de but selon chaque type de tirs pour la saison 2020")
plt.legend()
plt.show()

# %%
plt.bar(season_2021_df_shots['type_of_shot'], season_2021_df_shots['count'], label="tire au but", color='b')
plt.bar(season_2021_df_goals['type_of_shot'], season_2021_df_goals['count'], label="but", color='g')
plt.plot()

plt.xlabel("type de tir au but")
plt.ylabel("nombre de tirs")
plt.title("Le nombre de tirs au but contre le nombre de but selon chaque type de tirs pour la saison 2021")
plt.legend()
plt.show()

# %%
_season_2017_df = df_season_2017.copy()
_season_2018_df = df_season_2018.copy()
_season_2019_df = df_season_2019.copy()
_season_2020_df = df_season_2020.copy()
_season_2021_df = df_season_2021.copy()

# %%
_season_2017_df.drop(['about.periodTime','about.eventId','team.name','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
_season_2018_df.drop(['about.periodTime','about.eventId','team.name','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
_season_2019_df.drop(['about.periodTime','about.eventId','team.name','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
_season_2020_df.drop(['about.periodTime','about.eventId','team.name','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)
_season_2021_df.drop(['about.periodTime','about.eventId','team.name','players.0.player.fullName','players.1.player.fullName','result.strength.code','result.emptyNet'], inplace=True, axis=1)

# %%
left_side_goal = [-89,0]
right_side_goal = [89,0]
_season_2017_df.head()
# Out:
#   result.eventTypeId coordinates.x coordinates.y result.secondaryType
# 0               SHOT         -36.0         -28.0           Wrist Shot
# 1               SHOT         -75.0           1.0           Wrist Shot
# 2               SHOT         -73.0          10.0             Backhand
# 3               SHOT          80.0          -3.0           Wrist Shot
# 4               SHOT         -44.0         -21.0            Snap Shot
